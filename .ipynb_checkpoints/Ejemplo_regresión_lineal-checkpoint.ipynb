# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("second_hand_cars.csv")

df.head(3)
# Out:
#            Brand    Price   Body  Mileage  EngineV Engine Type Registration  \
# 0            BMW   4200.0  sedan      277      2.0      Petrol          yes
# 1  Mercedes-Benz   7900.0    van      427      2.9      Diesel          yes
# 2  Mercedes-Benz  13300.0  sedan      358      5.0         Gas          yes
#
#    Year         Model
# 0  1991           320
# 1  1999  Sprinter 212
# 2  2003         S 500

# %%
# Lo primero, eliminamos los nans

df.dropna(inplace = True)

# %%
# Veamos como se relacionan todas las columnas con "Price".

for col in df.columns:
    sns.scatterplot(x = df[col], y = df["Price"], color = "r")
    plt.show()

# %%
# Vamos a tomar la columna, de valores continuos: "Year".

df[["Year", "Price"]]
# Out:
#       Year     Price
# 0     1991    4200.0
# 1     1999    7900.0
# 2     2003   13300.0
# 3     2007   23000.0
# 4     2011   18300.0
# ...    ...       ...
# 4339  2014   17900.0
# 4340  2014  125000.0
# 4341  1999    6500.0
# 4342  1985    8000.0
# 4344  2013   13500.0
#
# [4025 rows x 2 columns]

# %%
X = df[["Year"]].values 
y = df[["Price"]].values

X.shape, y.shape
# Out:
# ((4025, 1), (4025, 1))

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30)

print(f"Conjunto de Train: {X_train.shape, y_train.shape}")
print(f"Conjunto de Test: {X_test.shape, y_test.shape}")
# Out:
# Conjunto de Train: ((2817, 1), (2817, 1))
# Conjunto de Test: ((1208, 1), (1208, 1))

# %%
# Algoritmo de regresión lineal de sklearn

regresion_lineal = LinearRegression()
regresion_lineal.fit(X_train, y_train)

# Encontramos los coeficientes de la recta  
print ("w_1:", regresion_lineal.coef_)
print ("w_0:", regresion_lineal.intercept_)
# Out:
# w_1: [[1923.27508173]]
# w_0: [-3839414.03739145]

# %%
### Grafico de la Regresión

b = regresion_lineal.intercept_[0]
m = regresion_lineal.coef_[0][0]

# Ecuación de una recta: y = m*x + b

print(f"y = {m}x + {b}")
# Out:
# y = 1923.2750817320589x + -3839414.037391447

# %%
plt.figure(figsize = (8, 5))

# Puntos de entrenamiento (X_train, y_train)
sns.scatterplot(x = X_train.flatten(), y = y_train.flatten(), color = "blue")


# Plot de la Regresión
ecuacion_recta = m*X_train.flatten() + b # Ecuación de la recta y = m*x + b

plt.plot(X_train.flatten(), ecuacion_recta, "red")


plt.grid()
plt.show()

# %%
# Predicciones

yhat = regresion_lineal.predict(X_test)

for i, j in zip(yhat[:5], y_test[:5]):
    print(f"Predicción:{i[0]} \tValor real:{j[0]}")
# Out:
# Predicción:20599.05164479511 	Valor real:10600.0
# Predicción:34061.97721691942 	Valor real:56500.0
# Predicción:34061.97721691942 	Valor real:85000.0
# Predicción:18675.776563063264 	Valor real:10900.0
# Predicción:37908.52738038357 	Valor real:64500.0

# %%
# Métricas
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
RAE = np.sum(np.abs(np.subtract(y_test, yhat))) / np.sum(np.abs(np.subtract(y_test, np.mean(y_test))))
RSE = np.sum(np.square(np.subtract(y_test, yhat))) / np.sum(np.square(np.subtract(y_test, np.mean(y_test))))
r2_ajustada = 1 - (1 - regresion_lineal.score(X_test, y_test))*(len(y_test) - 1)/(len(y_test) - X_test.shape[1] - 1)
print(f"MAE:\t {mean_absolute_error(yhat, y_test)}")
print(f"MSE:\t {mean_squared_error(yhat, y_test)}")
print(f"R**2:\t {r2_score(yhat, y_test)}")
print(f"RAE:\t {RAE}")
print(f"RSE:\t {RSE}")
print(f"Adjusted R**2:\t {r2_ajustada}")
# Out:
# MAE:	 12259.456056070721
# MSE:	 479935174.20072746
# R**2:	 -1.763139774488422
# RAE:	 0.8355988785483413
# RSE:	 0.7684139267827906
# Adjusted R**2:	 0.23094891407394014

# %%
# Veamos los valores de yhat, y_test y su diferencia

df_pred = pd.DataFrame()

df_pred["y_test"] = y_test.flatten()
df_pred["yhat"] = yhat.flatten()

df_pred["diferencia"] = round(abs((df_pred["y_test"] - df_pred["yhat"]) / df_pred["y_test"] * 100), 4)

df_pred = df_pred.sort_values("diferencia")

df_pred.head(20)
# Out:
#        y_test          yhat  diferencia
# 204   22500.0  22522.326727      0.0992
# 611   16800.0  16752.501481      0.2827
# 368   22600.0  22522.326727      0.3437
# 703   20500.0  20599.051645      0.4832
# 1198  28500.0  28292.151972      0.7293
# 1017  38233.0  37908.527380      0.8487
# 338    7200.0   7136.126073      0.8871
# 447   18500.0  18675.776563      0.9501
# 746   18500.0  18675.776563      0.9501
# 53    28000.0  28292.151972      1.0434
# 1058  15000.0  14829.226400      1.1385
# 435   15000.0  14829.226400      1.1385
# 547   27900.0  28292.151972      1.4056
# 239   28700.0  28292.151972      1.4211
# 315   20900.0  20599.051645      1.4399
# 728   14600.0  14829.226400      1.5700
# 263   18999.0  18675.776563      1.7013
# 298   31600.0  32138.702135      1.7048
# 788    8899.0   9059.401154      1.8025
# 665    7000.0   7136.126073      1.9447

# %%
df_pred.tail(20)
# Out:
#       y_test          yhat  diferencia
# 799   2650.0 -17866.449990    774.2057
# 622   2650.0 -17866.449990    774.2057
# 401   2500.0 -17866.449990    814.6580
# 268   2200.0 -15943.174908    824.6898
# 142   2350.0 -17866.449990    860.2745
# 642   2200.0 -17866.449990    912.1114
# 386   1900.0 -15943.174908    939.1145
# 403   2200.0 -19789.725072    999.5330
# 422   1900.0 -17866.449990   1040.3395
# 1034  1900.0 -17866.449990   1040.3395
# 657   2500.0 -23636.275235   1045.4510
# 932   1500.0 -15943.174908   1162.8783
# 917   2400.0 -25559.550317   1164.9813
# 699   2990.0 -33252.650644   1212.1288
# 344   1850.0 -21713.000153   1273.6757
# 714   1750.0 -21713.000153   1340.7429
# 245   1550.0 -19789.725072   1376.7565
# 821    999.0 -15943.174908   1695.9134
# 1027  1100.0 -21713.000153   2073.9091
# 958    600.0 -33252.650644   5642.1084

# %%
# Vamos a comparar que tan alejados estan los valores reales (y_test) y los valores predichos (y_train)

plt.figure(figsize = (8, 5))

sns.scatterplot(x = y_test.flatten(), y = yhat.flatten(), alpha = 0.5, color = "blue")

plt.xlabel("Valores Reales (y_train)", size = 18)
plt.ylabel("Predicciones (yhat)", size = 18)

plt.show()

# %%
# Si graficamos X_test vs y_test obtenemos la nube de puntos de valores reales

# Si graficamos X_test vs yhat obtenemos la "nube" de puntos de valores predichos

plt.figure(figsize = (8, 5))

plt.plot(X_test, y_test, marker = "o", linestyle = "", label = "y_test", alpha = 0.5)

plt.plot(X_test, yhat, marker = "o", linestyle = "", label = "yhat", alpha = 0.5)

plt.legend()
plt.show()
